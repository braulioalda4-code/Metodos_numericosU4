# %% [markdown]
# <a href="https://colab.research.google.com/github/braulioalda4-code/Metodos_numericosU4/blob/main/Regla_de_Simpson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ejercicio 2 - Regla de Simpson

# %%
a = 0 # Límite inferior
b = 2 # Límite superior
n = 1000 # Número de subintervalos (debe ser par)

h = (b-a)/n # Calcula el tamaño del paso

x = np.linspace(a,b,n+1) # Genera los nodos del intervalo

y = f(x) # Evalúa la función

suma = y[0] + y[n] # Inicializa la suma con extremos

for i in range(1,n): # Itera sobre los puntos interiores
    if i % 2 == 0: # Verifica si el índice es par
        suma += 2*y[i] # Aplica coeficiente 2
    else:
        suma += 4*y[i] # Aplica coeficiente 4

integral = (h/3)*suma # Aplica la fórmula de Simpson

print("Integral aproximada (Simpson):",integral) # Muestra resultado
# Out:
# Integral aproximada (Simpson): 2.666666666666665

# %% [markdown]
# <a href="https://colab.research.google.com/github/braulioalda4-code/Metodos_numericosU4/blob/main/Calculo_de_area.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejercicio 3 - Aplicacion IA : Calculo de area bajo la **curva**

# %%
import numpy as np #importa numpy

def f(x): #define la funcion tipo gaussiana
  return np.exp(-x**2) #calcula e^(-x^2)

a = 0 #limite inferior
b = 1 #limite superior
n = 100 #numero de iteraciones

h = (b-a)/n #calcula el tamaño del paso

x = np.linspace(a,b,n+1) #genera puntos

y = f(x) # evalua funcion

integral = (h/2)*(y[0]+2*sum(y[1:n])+y[n]) #Aplica

print("El area bajo la curva : ",integral) #resultado
# Out:
# El area bajo la curva :  0.7468180014679697
